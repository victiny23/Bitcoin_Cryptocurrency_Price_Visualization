# %%
import os
import numpy as np
import pandas as pd
# pkl compressed file
import pickle   
import quandl

import plotly.offline as py
import plotly.graph_objs as go
py.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
quandl.ApiConfig.api_key = 'LLz3seEtf9djqdmdMZAL'

# %%
def get_quandl_data(quandl_code):
    cache_path = '{}.pkl'.format(quandl_code).replace('/', '-')
    try:
        f = open(cache_path, 'rb')
        df = pickle.load(f)
        print('Loaded {} from cache'.format(quandl_code))
    except (OSError, IOError) as e:
        df = quandl.get(quandl_code, returns='pandas')
        df.to_pickle(cache_path)
        print('Cached {} at {}'.format(quandl_code, cache_path))
    return df

# %%
btc_usd_kraken = get_quandl_data('BCHARTS/KRAKENUSD')
# Out:
# Cached BCHARTS/KRAKENUSD at BCHARTS-KRAKENUSD.pkl

# %%
btc_usd_kraken
# Out:
#                    Open         High          Low        Close  Volume (BTC)  \
# Date
# 2014-01-07    874.67040    892.06753    810.00000    810.00000     15.622378
# 2014-01-08    810.00000    899.84281    788.00000    824.98287     19.182756
# 2014-01-09    825.56345    870.00000    807.42084    841.86934      8.158335
# 2014-01-10    839.99000    857.34056    817.00000    857.33056      8.024510
# 2014-01-11    858.20000    918.05471    857.16554    899.84105     18.748285
# ...                 ...          ...          ...          ...           ...
# 2020-09-23  10531.20000  10534.00000  10134.60000  10230.70000   4306.722978
# 2020-09-24  10230.70000  10788.30000  10192.40000  10740.20000   4593.252937
# 2020-09-25  10738.90000  10761.60000  10565.00000  10695.10000   3847.358268
# 2020-09-26  10695.30000  10835.00000  10662.20000  10733.30000   1457.363815
# 2020-09-27  10733.40000  10799.00000  10600.00000  10754.30000   1476.914348
#
#             Volume (Currency)  Weighted Price
# Date
# 2014-01-07       1.315147e+04      841.835522
# 2014-01-08       1.609733e+04      839.156269
# 2014-01-09       6.784250e+03      831.572913
# 2014-01-10       6.780220e+03      844.938794
# 2014-01-11       1.669857e+04      890.671709
# ...                       ...             ...
# 2020-09-23       4.467538e+07    10373.404005
# 2020-09-24       4.825500e+07    10505.625991
# 2020-09-25       4.103778e+07    10666.483039
# 2020-09-26       1.563151e+07    10725.881660
# 2020-09-27       1.581677e+07    10709.332462
#
# [2456 rows x 7 columns]
